# %% [markdown]
# Question: Does it make sense to have a longer transmitter outside of the measuring location just to increase the transmitter moment?
#
# We consider a drone EM case with flight distances of about 1km in x direction.
#
# Default case is a 1km long transmitter in y direction (symmetric around Rx line) that could be prolonged by another km into one direction.

# %%
import numpy as np
from saem import CSEMData

# %%
x = np.array([50, 100, 200, 400, 800])
f = 2**(np.arange(11)) * 32
print(f)
# Out:
# [   32    64   128   256   512  1024  2048  4096  8192 16384 32768]

# %%
short = CSEMData(f=f, rx=x, txPos=[[0, 0], [-500, 500]])
short.showPos();
# Out:
# c:\Program Files\software\Anaconda\envs\py38\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Program Files\software\Anaconda\envs\py38\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\1296607482.py in <cell line: 1>()
# ----> 1 short = CSEMData(f=f, rx=x, txPos=[[0, 0], [-500, 500]])
#       2 short.showPos();
#
# C:\Guenther.T\src\SAEM\saem\saem.py in __init__(self, datafile, **kwargs)
#      50         super().__init__()
#      51
# ---> 52         self.updateData(**kwargs)
#      53         self.isLoop = False
#      54         self.txAlt = kwargs.pop("txalt", 0.0)
#
# C:\Guenther.T\src\SAEM\saem\emdata.py in updateData(self, **kwargs)
#      82         self.ry = kwargs.pop("ry", np.array([0.]))
#      83         self.rz = kwargs.pop("rz", np.array([0.]))
# ---> 84         dxy = np.sqrt(np.diff(self.rx)**2 + np.diff(self.ry)**2)
#      85         self.radius = np.median(dxy) * 0.5
#      86         self.line = kwargs.pop("line", np.ones_like(self.rx, dtype=int))
#
# ValueError: operands could not be broadcast together with shapes (4,) (0,)

# %%
long = CSEMData(f=f, rx=x, txPos=[[0, 0], [-500, 1500]])
long.showPos();

# %%
rho = [300, 30]
thk = [70]
short.simulate(rho=rho, thk=thk)
long.simulate(rho=rho, thk=thk)

# %%
short.DATA = short.RESP
long.DATA = long.RESP

# %%
short.showLineData(1);
# Out:
# (11, 5)
# (11, 5)
# (11, 5)

# %%
long.showLineData(1);
# Out:
# (11, 5)
# (11, 5)
# (11, 5)

# %%
short.setPos(0, show=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\2655394366.py in <cell line: 1>()
# ----> 1 short.setPos(0, show=True)
#
# NameError: name 'short' is not defined

# %%
nx = 4
print(x[nx])
ax = short.showSounding(nx, amphi=False, cmp=[0, 0, 1], label="short", color="C0")
long.showSounding(nx, amphi=False, cmp=[0, 0, 1], label="long", color="C1", ax=ax);
# Out:
# 800

# %%
import numpy as np
from saem import CSEMData

# %%
# Definition of transmitter
txpos = np.array([[559497.46, 5784467.953],
                  [559026.532, 5784301.022]]).T
ground = 70  #  altitude of ground

# %%
# read in the old data and take every second data point (12->24m)
self = CSEMData(datafile="data_f[1-3].mat", txPos=txpos, txalt=ground)
self.showField("alt")
self.filter(every=2)
self.showField("alt");
# Out:
# read data_f1.mat
# reading data_f2.mat
# reading data_f3.mat
# (<matplotlib.axes._subplots.AxesSubplot at 0x1da1d4c99a0>,
#  <matplotlib.colorbar.Colorbar at 0x1da1d6791f0>)

# %%
# read in the second part (already 24m distance)
part2 = CSEMData(datafile="newdata_f*.mat", txPos=txpos, txalt=ground)
part2.showField("alt")
self.addData(part2)
self.showField("alt");
# Out:
# read newdata_f4.mat
# reading newdata_f5.mat
# reading newdata_f6_1.mat
# reading newdata_f6_2.mat
# reading newdata_f7.mat
# (<matplotlib.axes._subplots.AxesSubplot at 0x1da1d5ff3d0>,
#  <matplotlib.colorbar.Colorbar at 0x1da1d88dc10>)

# %%
# display single frequency data
nf = 5  # frequency index for checking
self.showData(nf=nf);
# Out:
# C:\Guenther.T\src\SAEM\saem\plotting.py:94: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.
#   norm = SymLogNorm(linthresh=alim[0], vmin=-alim[1], vmax=alim[1])
# (<Figure size 864x432 with 12 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA1D7A29A0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA1D6124F0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA1D819730>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA1D658490>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA1D8344C0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA1D5EC1C0>]],
#        dtype=object))

# %%
# make 0D simulation to check signs and behaviour
self.simulate(rho=25)
self.showData(nf=nf, what="response")
# Out:
# C:\Guenther.T\src\SAEM\saem\plotting.py:94: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.
#   norm = SymLogNorm(linthresh=alim[0], vmin=-alim[1], vmax=alim[1])
# (<Figure size 864x432 with 12 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA21D64F10>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20F75880>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20C04940>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20D476A0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA21174820>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20DF2160>]],
#        dtype=object))

# %%
# filter according to transmitter distance
self.filter(minTxDist=100, maxTxDist=700)
self.showData(nf=nf)
# Out:
# C:\Guenther.T\src\SAEM\saem\plotting.py:94: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.
#   norm = SymLogNorm(linthresh=alim[0], vmin=-alim[1], vmax=alim[1])
# (<Figure size 864x432 with 12 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20E6FDC0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20F67E20>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA2205AA60>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA237A2850>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20A3F460>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA20EF52E0>]],
#        dtype=object))
